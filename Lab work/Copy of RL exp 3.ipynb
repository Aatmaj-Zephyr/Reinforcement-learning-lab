# %%
import gym

# Create the Blackjack environment
env = gym.make('Blackjack-v1')
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
def basic_policy(state):
    """
    A simple policy that hits if the player's sum is less than 20, else holds.
    """
    player_sum, dealer_sum, usable_ace = state
    return 0 if player_sum >= 20 else 1  # 0 = hold, 1 = hit

def play_episode(policy, env):
    """
    Plays an episode of Blackjack using the given policy.

    Args:
        policy: A function that takes a state and returns an action (0=hold, 1=hit).
        env: The Blackjack environment.

    Returns:
        A tuple (states, actions, rewards) for the episode.
    """
    states = []
    actions = []
    rewards = []

    state = env.reset()
    while True:
        states.append(state)
        action = policy(state)
        actions.append(action)
        next_state, reward, done, _ = env.step(action)
        rewards.append(reward)
        state = next_state
        if done:
            break

    return states, actions, rewards

# %%
from collections import defaultdict

def monte_carlo_policy_evaluation(policy, env, num_episodes, discount_factor=1.0):
    """
    Evaluate a policy using Monte Carlo sampling.

    Args:
        policy: A function that takes a state and returns an action.
        env: The environment.
        num_episodes: Number of episodes to sample.
        discount_factor: Discount factor for future rewards.

    Returns:
        A dictionary mapping state to value.
    """
    # Store returns for each state
    returns_sum = defaultdict(float)
    returns_count = defaultdict(int)
    V = defaultdict(float)

    for _ in range(num_episodes):
        # Generate an episode using the policy
        episode = play_episode(policy, env)
        states, _, rewards = episode

        # Calculate returns
        G = 0
        for t in reversed(range(len(states))):
            G = rewards[t] + discount_factor * G
            state = states[t]
            # First visit Monte Carlo: only consider first time state is visited in episode
            if state not in states[:t]:
                returns_sum[state] += G
                returns_count[state] += 1
                V[state] = returns_sum[state] / returns_count[state]

    return V

# Example usage: Evaluate the initial policy with many episodes
V = monte_carlo_policy_evaluation(basic_policy, env, num_episodes=5000)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %%
V
# Out:
# defaultdict(float,
#             {(18, 2, False): -0.631578947368421,
#              (13, 2, False): -0.5555555555555556,
#              (19, 1, False): -0.8333333333333334,
#              (16, 1, False): -0.8793103448275862,
#              (17, 9, False): -0.7746478873239436,
#              (11, 9, False): 0.03571428571428571,
#              (6, 9, False): -0.42857142857142855,
#              (18, 10, False): -0.7188940092165899,
#              (11, 10, False): -0.08421052631578947,
#              (20, 2, False): 0.7076923076923077,
#              (10, 2, False): -0.2777777777777778,
#              (8, 2, False): -0.5555555555555556,
#              (20, 9, False): 0.7195121951219512,
#              (20, 5, False): 0.6582278481012658,
#              (17, 8, False): -0.56,
#              (21, 9, True): 1.0,
#              (15, 10, False): -0.6740331491712708,
#              (21, 8, False): 0.9347826086956522,
#              (14, 8, False): -0.3333333333333333,
#              (18, 3, False): -0.84,
#              (19, 9, False): -0.6727272727272727,
#              (19, 9, True): -0.5833333333333334,
#              (16, 7, False): -0.8936170212765957,
#              (19, 7, True): 0.2,
#              (18, 7, True): 0.0,
#              (18, 4, False): -0.6097560975609756,
#              (19, 10, False): -0.8148148148148148,
#              (17, 10, False): -0.7165775401069518,
#              (13, 3, False): -0.7959183673469388,
#              (12, 3, False): -0.7272727272727273,
#              (11, 3, False): -0.09090909090909091,
#              (13, 5, False): -0.7321428571428571,
#              (12, 10, False): -0.5114942528735632,
#              (10, 10, False): -0.1891891891891892,
#              (20, 4, False): 0.6901408450704225,
#              (17, 4, False): -0.7857142857142857,
#              (17, 4, True): -0.8571428571428571,
#              (20, 1, False): 0.2608695652173913,
#              (13, 1, False): -0.7391304347826086,
#              (12, 1, False): -0.5416666666666666,
#              (16, 2, False): -0.7272727272727273,
#              (16, 4, False): -0.7291666666666666,
#              (14, 1, False): -0.7413793103448276,
#              (18, 5, False): -0.6153846153846154,
#              (18, 5, True): 0.0,
#              (7, 5, False): -0.36363636363636365,
#              (16, 10, False): -0.7227272727272728,
#              (14, 2, False): -0.6111111111111112,
#              (20, 8, False): 0.7469879518072289,
#              (17, 3, False): -0.7608695652173914,
#              (15, 3, False): -0.6078431372549019,
#              (14, 3, False): -0.48,
#              (10, 3, False): -0.19230769230769232,
#              (21, 10, False): 0.8979591836734694,
#              (17, 1, False): -0.8428571428571429,
#              (9, 1, False): -0.75,
#              (20, 10, False): 0.45714285714285713,
#              (19, 10, True): -0.4878048780487805,
#              (15, 10, True): -0.6842105263157895,
#              (21, 10, True): 0.9294117647058824,
#              (13, 10, False): -0.6331658291457286,
#              (17, 5, False): -0.6612903225806451,
#              (11, 5, False): -0.07407407407407407,
#              (17, 7, False): -0.746031746031746,
#              (21, 3, False): 0.8648648648648649,
#              (14, 10, False): -0.6727272727272727,
#              (7, 10, False): -0.4473684210526316,
#              (20, 6, False): 0.6388888888888888,
#              (19, 6, False): -0.6792452830188679,
#              (16, 6, False): -0.3333333333333333,
#              (13, 6, False): -0.7435897435897436,
#              (19, 8, False): -0.6451612903225806,
#              (20, 7, True): 1.0,
#              (13, 7, True): 1.0,
#              (16, 3, False): -0.6382978723404256,
#              (17, 2, False): -0.47619047619047616,
#              (21, 4, False): 0.8055555555555556,
#              (19, 4, False): -0.6491228070175439,
#              (13, 4, False): -0.4782608695652174,
#              (7, 4, False): -0.4444444444444444,
#              (15, 7, False): -0.6181818181818182,
#              (14, 9, False): -0.625,
#              (18, 8, False): -0.6363636363636364,
#              (7, 2, False): -1.0,
#              (21, 5, True): 1.0,
#              (15, 5, False): -0.7307692307692307,
#              (13, 8, False): -0.46,
#              (17, 8, True): -0.2,
#              (16, 10, True): -0.5652173913043478,
#              (20, 10, True): 0.5681818181818182,
#              (17, 7, True): -0.6666666666666666,
#              (20, 3, False): 0.6794871794871795,
#              (9, 3, False): -0.5555555555555556,
#              (12, 5, False): -0.3076923076923077,
#              (19, 5, True): -0.23076923076923078,
#              (8, 5, False): -0.6428571428571429,
#              (15, 6, False): -0.6481481481481481,
#              (11, 6, False): -0.38461538461538464,
#              (12, 6, False): -0.4186046511627907,
#              (20, 3, True): 1.0,
#              (17, 10, True): -0.2857142857142857,
#              (20, 7, False): 0.647887323943662,
#              (10, 5, False): -0.045454545454545456,
#              (6, 5, False): -0.5555555555555556,
#              (12, 7, False): -0.5531914893617021,
#              (21, 6, False): 0.8611111111111112,
#              (17, 6, False): -0.5918367346938775,
#              (13, 10, True): -0.45,
#              (19, 3, False): -0.7037037037037037,
#              (11, 8, False): 0.05555555555555555,
#              (14, 10, True): -0.45,
#              (21, 1, True): 0.7222222222222222,
#              (6, 7, False): -0.7142857142857143,
#              (9, 10, False): -0.53125,
#              (18, 9, False): -0.7627118644067796,
#              (16, 9, False): -0.6901408450704225,
#              (15, 4, False): -0.8367346938775511,
#              (10, 1, False): -0.30434782608695654,
#              (21, 1, False): 0.7692307692307693,
#              (11, 1, False): -0.38461538461538464,
#              (21, 8, True): 0.9642857142857143,
#              (13, 9, False): -0.6041666666666666,
#              (21, 3, True): 1.0,
#              (21, 2, False): 0.8620689655172413,
#              (19, 2, False): -0.7380952380952381,
#              (21, 5, False): 0.8,
#              (12, 9, False): -0.43478260869565216,
#              (8, 9, False): -0.45454545454545453,
#              (5, 9, False): -0.5,
#              (15, 2, False): -0.8484848484848485,
#              (12, 2, False): -0.5490196078431373,
#              (8, 10, False): -0.7037037037037037,
#              (9, 8, False): -0.5,
#              (8, 8, False): -0.6470588235294118,
#              (16, 9, True): -1.0,
#              (18, 6, False): -0.8135593220338984,
#              (8, 6, False): -0.3333333333333333,
#              (16, 5, False): -0.6785714285714286,
#              (15, 1, False): -0.8301886792452831,
#              (16, 8, False): -0.6,
#              (21, 7, True): 1.0,
#              (18, 1, False): -0.7592592592592593,
#              (8, 1, False): -0.6428571428571429,
#              (10, 8, False): -0.16666666666666666,
#              (18, 10, True): -0.3125,
#              (11, 2, False): -0.5555555555555556,
#              (21, 9, False): 0.8648648648648649,
#              (9, 2, False): -0.75,
#              (5, 3, False): -1.0,
#              (17, 2, True): -0.7142857142857143,
#              (14, 4, False): -0.5740740740740741,
#              (9, 6, False): -0.35714285714285715,
#              (6, 6, False): -0.42857142857142855,
#              (14, 5, False): -0.6756756756756757,
#              (12, 4, False): -0.48936170212765956,
#              (19, 5, False): -0.8142857142857143,
#              (14, 6, False): -0.62,
#              (18, 8, True): -0.5714285714285714,
#              (16, 8, True): -1.0,
#              (13, 7, False): -0.8222222222222222,
#              (21, 2, True): 1.0,
#              (16, 5, True): -0.4,
#              (14, 7, False): -0.5319148936170213,
#              (12, 8, False): -0.74,
#              (21, 6, True): 0.92,
#              (10, 4, False): -0.16666666666666666,
#              (5, 4, False): -0.6,
#              (15, 9, False): -0.47058823529411764,
#              (6, 10, False): -0.4482758620689655,
#              (7, 8, False): -0.6,
#              (16, 2, True): -0.6666666666666666,
#              (19, 7, False): -0.8909090909090909,
#              (11, 4, False): 0.2222222222222222,
#              (18, 6, True): -0.5,
#              (8, 3, False): -1.0,
#              (15, 5, True): -0.2,
#              (16, 6, True): -0.45454545454545453,
#              (6, 2, False): -0.8,
#              (17, 1, True): -0.3333333333333333,
#              (10, 6, False): -0.10526315789473684,
#              (5, 6, False): -0.14285714285714285,
#              (10, 7, False): -0.55,
#              (12, 2, True): -0.6,
#              (14, 1, True): -0.2857142857142857,
#              (16, 3, True): -1.0,
#              (7, 9, False): -0.3333333333333333,
#              (15, 8, False): -0.7111111111111111,
#              (5, 10, False): -0.2857142857142857,
#              (14, 3, True): -1.0,
#              (4, 1, False): -0.3333333333333333,
#              (9, 5, False): -0.6666666666666666,
#              (7, 1, False): -0.42857142857142855,
#              (5, 1, False): -0.6666666666666666,
#              (6, 4, False): -0.75,
#              (15, 8, True): -0.7142857142857143,
#              (4, 8, False): 0.3333333333333333,
#              (15, 9, True): -0.7142857142857143,
#              (21, 4, True): 1.0,
#              (20, 4, True): 1.0,
#              (14, 4, True): 0.25,
#              (13, 5, True): -0.14285714285714285,
#              (19, 2, True): -0.7142857142857143,
#              (14, 2, True): 0.3333333333333333,
#              (14, 6, True): -1.0,
#              (6, 1, False): -0.5,
#              (13, 6, True): -0.6,
#              (19, 6, True): -0.7777777777777778,
#              (20, 9, True): 0.8181818181818182,
#              (14, 9, True): 0.0,
#              (4, 10, False): -0.5833333333333334,
#              (12, 4, True): 1.0,
#              (21, 7, False): 0.9375,
#              (8, 4, False): -0.8181818181818182,
#              (19, 8, True): -0.6,
#              (10, 9, False): 0.0,
#              (20, 8, True): 1.0,
#              (6, 8, False): 0.2,
#              (13, 2, True): -0.5,
#              (17, 5, True): -0.36363636363636365,
#              (7, 3, False): -0.5555555555555556,
#              (11, 7, False): 0.2631578947368421,
#              (7, 7, False): 0.0,
#              (9, 9, False): -0.4782608695652174,
#              (4, 3, False): -1.0,
#              (20, 5, True): 0.375,
#              (9, 4, False): -0.2857142857142857,
#              (20, 6, True): 0.375,
#              (20, 1, True): 0.0,
#              (18, 2, True): -0.75,
#              (15, 2, True): 0.0,
#              (13, 8, True): -1.0,
#              (16, 7, True): -1.0,
#              (19, 1, True): -1.0,
#              (4, 4, False): -1.0,
#              (18, 1, True): -0.8181818181818182,
#              (20, 2, True): 0.14285714285714285,
#              (14, 5, True): -0.3333333333333333,
#              (15, 1, True): -0.6,
#              (18, 7, False): -0.7021276595744681,
#              (19, 3, True): -0.3333333333333333,
#              (9, 7, False): -0.6470588235294118,
#              (16, 1, True): -1.0,
#              (12, 10, True): -0.875,
#              (6, 3, False): -0.8,
#              (14, 8, True): -1.0,
#              (12, 8, True): -1.0,
#              (13, 3, True): -1.0,
#              (17, 6, True): 0.0,
#              (13, 1, True): -0.25,
#              (15, 7, True): -0.42857142857142855,
#              (5, 8, False): -1.0,
#              (5, 5, False): -0.6,
#              (18, 3, True): -1.0,
#              (4, 6, False): 0.4,
#              (8, 7, False): -0.8333333333333334,
#              (15, 6, True): 0.2,
#              (15, 4, True): -0.6666666666666666,
#              (18, 9, True): -0.6,
#              (14, 7, True): -0.3333333333333333,
#              (5, 2, False): -0.5,
#              (18, 4, True): -1.0,
#              (4, 5, False): 1.0,
#              (17, 9, True): -0.7142857142857143,
#              (19, 4, True): -0.5,
#              (13, 4, True): -0.6,
#              (7, 6, False): -0.4,
#              (16, 4, True): -0.5,
#              (12, 7, True): 0.0,
#              (12, 1, True): -1.0,
#              (13, 9, True): -1.0,
#              (4, 9, False): -0.3333333333333333,
#              (4, 7, False): 1.0,
#              (12, 5, True): -0.3333333333333333,
#              (12, 6, True): -1.0,
#              (5, 7, False): -0.3333333333333333,
#              (17, 3, True): -1.0,
#              (4, 2, False): -1.0})

# %%
def greedy_policy_from_value_function(V, env):
    """
    Create a greedy policy based on the given value function.

    Args:
        V: A dictionary mapping state to value.
        env: The environment.

    Returns:
        A policy function that maps state to action.
    """
    def policy(state):
        # Get the player's sum and other details from the state
        player_sum, dealer_card, usable_ace = state

        # Calculate the value of holding (i.e., not taking another card)
        hold_value = V[state] if state in V else 0

        # Calculate the value of hitting (i.e., taking another card)
        hit_value = float('-inf')  # Start with the lowest possible value

        if player_sum < 21:  # If the player's sum is less than 21, consider hitting
            for card_value in range(1, 11):  # Possible values of the next card
                next_player_sum = player_sum + card_value

                # If adding the card causes the player to go bust (over 21) with a usable ace, reduce the sum by 10
                if next_player_sum > 21 and usable_ace:
                    next_player_sum -= 10
                    usable_ace = False

                # Check the value of the next state
                next_state = (next_player_sum, dealer_card, usable_ace)
                if next_state in V:
                    hit_value = max(hit_value, V[next_state])

        # Return 1 for "hit" if hitting provides a higher value, otherwise return 0 for "hold"
        return 1 if hit_value > hold_value else 0

    return policy

# %%
def evaluate_policy(policy, env, num_episodes):
    """
    Evaluate the performance of a policy by running multiple episodes.

    Args:
        policy: A policy function that maps state to action.
        env: The environment.
        num_episodes: Number of episodes to evaluate.

    Returns:
        The average return over the episodes.
    """
    total_return = 0

    for _ in range(num_episodes):
        states, _, rewards = play_episode(policy, env)
        total_return += sum(rewards)

    return total_return / num_episodes

# Evaluate the optimal policy
num_test_episodes = 1000
average_return = evaluate_policy(improved_policy, env, num_test_episodes)

print(f"Average return of the optimal policy over {num_test_episodes} episodes: {average_return:.2f}")
# Out:
# Average return of the optimal policy over 1000 episodes: -0.53

# %%
def monte_carlo_policy_iteration(env, num_episodes, discount_factor=1, tol=1e-10):
    """
    Perform Monte Carlo Policy Iteration to find an optimal policy.

    Args:
        env: The environment.
        num_episodes: Number of episodes to sample for policy evaluation.
        discount_factor: Discount factor for future rewards.
        tol: Convergence tolerance for policy improvement.

    Returns:
        A tuple (optimal_policy, optimal_value_function).
    """
    # Initialize a random policy
    policy = basic_policy  # initial policy
    V = defaultdict(float)
    counter = 0
    while True:
        counter += 1

        average_return = evaluate_policy(policy, env, num_test_episodes)

        print(f"Iteration number {counter} trained model for {num_episodes} episodes, Tested for {num_test_episodes} has average return {average_return:.2f}")
        if(counter >100):
          break
        # Policy Evaluation
        V_new = monte_carlo_policy_evaluation(policy, env, num_episodes, discount_factor)

        # Policy Improvement
        new_policy = greedy_policy_from_value_function(V_new, env)



        # Check for convergence
        if max(abs(V_new[state] - V[state]) for state in V_new) < tol:
            break


        # Update policy and value function
        policy = new_policy
        V = V_new

    return policy, V

# Perform Monte Carlo Policy Iteration
improved_policy, optimal_value_function = monte_carlo_policy_iteration(env, num_episodes=5000)
# Out:
# Iteration number 1 trained model for 5000 episodes, Tested for 1000 has average return -0.34
# Iteration number 2 trained model for 5000 episodes, Tested for 1000 has average return -0.63
# Iteration number 3 trained model for 5000 episodes, Tested for 1000 has average return -0.62
# Iteration number 4 trained model for 5000 episodes, Tested for 1000 has average return -0.62
# Iteration number 5 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 6 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 7 trained model for 5000 episodes, Tested for 1000 has average return -0.63
# Iteration number 8 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 9 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 10 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 11 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 12 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 13 trained model for 5000 episodes, Tested for 1000 has average return -0.68
# Iteration number 14 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 15 trained model for 5000 episodes, Tested for 1000 has average return -0.61
# Iteration number 16 trained model for 5000 episodes, Tested for 1000 has average return -0.68
# Iteration number 17 trained model for 5000 episodes, Tested for 1000 has average return -0.71
# Iteration number 18 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 19 trained model for 5000 episodes, Tested for 1000 has average return -0.59
# Iteration number 20 trained model for 5000 episodes, Tested for 1000 has average return -0.63
# Iteration number 21 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 22 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 23 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 24 trained model for 5000 episodes, Tested for 1000 has average return -0.69
# Iteration number 25 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 26 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 27 trained model for 5000 episodes, Tested for 1000 has average return -0.69
# Iteration number 28 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 29 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 30 trained model for 5000 episodes, Tested for 1000 has average return -0.69
# Iteration number 31 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 32 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 33 trained model for 5000 episodes, Tested for 1000 has average return -0.63
# Iteration number 34 trained model for 5000 episodes, Tested for 1000 has average return -0.68
# Iteration number 35 trained model for 5000 episodes, Tested for 1000 has average return -0.68
# Iteration number 36 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 37 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 38 trained model for 5000 episodes, Tested for 1000 has average return -0.68
# Iteration number 39 trained model for 5000 episodes, Tested for 1000 has average return -0.72
# Iteration number 40 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 41 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 42 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 43 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 44 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 45 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 46 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 47 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 48 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 49 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 50 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 51 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 52 trained model for 5000 episodes, Tested for 1000 has average return -0.72
# Iteration number 53 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 54 trained model for 5000 episodes, Tested for 1000 has average return -0.62
# Iteration number 55 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 56 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 57 trained model for 5000 episodes, Tested for 1000 has average return -0.62
# Iteration number 58 trained model for 5000 episodes, Tested for 1000 has average return -0.68
# Iteration number 59 trained model for 5000 episodes, Tested for 1000 has average return -0.74
# Iteration number 60 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 61 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 62 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 63 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 64 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 65 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 66 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 67 trained model for 5000 episodes, Tested for 1000 has average return -0.68
# Iteration number 68 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 69 trained model for 5000 episodes, Tested for 1000 has average return -0.70
# Iteration number 70 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 71 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 72 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 73 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 74 trained model for 5000 episodes, Tested for 1000 has average return -0.59
# Iteration number 75 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 76 trained model for 5000 episodes, Tested for 1000 has average return -0.70
# Iteration number 77 trained model for 5000 episodes, Tested for 1000 has average return -0.69
# Iteration number 78 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 79 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 80 trained model for 5000 episodes, Tested for 1000 has average return -0.63
# Iteration number 81 trained model for 5000 episodes, Tested for 1000 has average return -0.63
# Iteration number 82 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 83 trained model for 5000 episodes, Tested for 1000 has average return -0.61
# Iteration number 84 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 85 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 86 trained model for 5000 episodes, Tested for 1000 has average return -0.68
# Iteration number 87 trained model for 5000 episodes, Tested for 1000 has average return -0.68
# Iteration number 88 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 89 trained model for 5000 episodes, Tested for 1000 has average return -0.68
# Iteration number 90 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 91 trained model for 5000 episodes, Tested for 1000 has average return -0.61
# Iteration number 92 trained model for 5000 episodes, Tested for 1000 has average return -0.63
# Iteration number 93 trained model for 5000 episodes, Tested for 1000 has average return -0.67
# Iteration number 94 trained model for 5000 episodes, Tested for 1000 has average return -0.62
# Iteration number 95 trained model for 5000 episodes, Tested for 1000 has average return -0.66
# Iteration number 96 trained model for 5000 episodes, Tested for 1000 has average return -0.65
# Iteration number 97 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 98 trained model for 5000 episodes, Tested for 1000 has average return -0.68
# Iteration number 99 trained model for 5000 episodes, Tested for 1000 has average return -0.62
# Iteration number 100 trained model for 5000 episodes, Tested for 1000 has average return -0.64
# Iteration number 101 trained model for 5000 episodes, Tested for 1000 has average return -0.64

# %%
V
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# defaultdict(float,
#             {(18, 2, False): -0.631578947368421,
#              (13, 2, False): -0.5555555555555556,
#              (19, 1, False): -0.8333333333333334,
#              (16, 1, False): -0.8793103448275862,
#              (17, 9, False): -0.7746478873239436,
#              (11, 9, False): 0.03571428571428571,
#              (6, 9, False): -0.42857142857142855,
#              (18, 10, False): -0.7188940092165899,
#              (11, 10, False): -0.08421052631578947,
#              (20, 2, False): 0.7076923076923077,
#              (10, 2, False): -0.2777777777777778,
#              (8, 2, False): -0.5555555555555556,
#              (20, 9, False): 0.7195121951219512,
#              (20, 5, False): 0.6582278481012658,
#              (17, 8, False): -0.56,
#              (21, 9, True): 1.0,
#              (15, 10, False): -0.6740331491712708,
#              (21, 8, False): 0.9347826086956522,
#              (14, 8, False): -0.3333333333333333,
#              (18, 3, False): -0.84,
#              (19, 9, False): -0.6727272727272727,
#              (19, 9, True): -0.5833333333333334,
#              (16, 7, False): -0.8936170212765957,
#              (19, 7, True): 0.2,
#              (18, 7, True): 0.0,
#              (18, 4, False): -0.6097560975609756,
#              (19, 10, False): -0.8148148148148148,
#              (17, 10, False): -0.7165775401069518,
#              (13, 3, False): -0.7959183673469388,
#              (12, 3, False): -0.7272727272727273,
#              (11, 3, False): -0.09090909090909091,
#              (13, 5, False): -0.7321428571428571,
#              (12, 10, False): -0.5114942528735632,
#              (10, 10, False): -0.1891891891891892,
#              (20, 4, False): 0.6901408450704225,
#              (17, 4, False): -0.7857142857142857,
#              (17, 4, True): -0.8571428571428571,
#              (20, 1, False): 0.2608695652173913,
#              (13, 1, False): -0.7391304347826086,
#              (12, 1, False): -0.5416666666666666,
#              (16, 2, False): -0.7272727272727273,
#              (16, 4, False): -0.7291666666666666,
#              (14, 1, False): -0.7413793103448276,
#              (18, 5, False): -0.6153846153846154,
#              (18, 5, True): 0.0,
#              (7, 5, False): -0.36363636363636365,
#              (16, 10, False): -0.7227272727272728,
#              (14, 2, False): -0.6111111111111112,
#              (20, 8, False): 0.7469879518072289,
#              (17, 3, False): -0.7608695652173914,
#              (15, 3, False): -0.6078431372549019,
#              (14, 3, False): -0.48,
#              (10, 3, False): -0.19230769230769232,
#              (21, 10, False): 0.8979591836734694,
#              (17, 1, False): -0.8428571428571429,
#              (9, 1, False): -0.75,
#              (20, 10, False): 0.45714285714285713,
#              (19, 10, True): -0.4878048780487805,
#              (15, 10, True): -0.6842105263157895,
#              (21, 10, True): 0.9294117647058824,
#              (13, 10, False): -0.6331658291457286,
#              (17, 5, False): -0.6612903225806451,
#              (11, 5, False): -0.07407407407407407,
#              (17, 7, False): -0.746031746031746,
#              (21, 3, False): 0.8648648648648649,
#              (14, 10, False): -0.6727272727272727,
#              (7, 10, False): -0.4473684210526316,
#              (20, 6, False): 0.6388888888888888,
#              (19, 6, False): -0.6792452830188679,
#              (16, 6, False): -0.3333333333333333,
#              (13, 6, False): -0.7435897435897436,
#              (19, 8, False): -0.6451612903225806,
#              (20, 7, True): 1.0,
#              (13, 7, True): 1.0,
#              (16, 3, False): -0.6382978723404256,
#              (17, 2, False): -0.47619047619047616,
#              (21, 4, False): 0.8055555555555556,
#              (19, 4, False): -0.6491228070175439,
#              (13, 4, False): -0.4782608695652174,
#              (7, 4, False): -0.4444444444444444,
#              (15, 7, False): -0.6181818181818182,
#              (14, 9, False): -0.625,
#              (18, 8, False): -0.6363636363636364,
#              (7, 2, False): -1.0,
#              (21, 5, True): 1.0,
#              (15, 5, False): -0.7307692307692307,
#              (13, 8, False): -0.46,
#              (17, 8, True): -0.2,
#              (16, 10, True): -0.5652173913043478,
#              (20, 10, True): 0.5681818181818182,
#              (17, 7, True): -0.6666666666666666,
#              (20, 3, False): 0.6794871794871795,
#              (9, 3, False): -0.5555555555555556,
#              (12, 5, False): -0.3076923076923077,
#              (19, 5, True): -0.23076923076923078,
#              (8, 5, False): -0.6428571428571429,
#              (15, 6, False): -0.6481481481481481,
#              (11, 6, False): -0.38461538461538464,
#              (12, 6, False): -0.4186046511627907,
#              (20, 3, True): 1.0,
#              (17, 10, True): -0.2857142857142857,
#              (20, 7, False): 0.647887323943662,
#              (10, 5, False): -0.045454545454545456,
#              (6, 5, False): -0.5555555555555556,
#              (12, 7, False): -0.5531914893617021,
#              (21, 6, False): 0.8611111111111112,
#              (17, 6, False): -0.5918367346938775,
#              (13, 10, True): -0.45,
#              (19, 3, False): -0.7037037037037037,
#              (11, 8, False): 0.05555555555555555,
#              (14, 10, True): -0.45,
#              (21, 1, True): 0.7222222222222222,
#              (6, 7, False): -0.7142857142857143,
#              (9, 10, False): -0.53125,
#              (18, 9, False): -0.7627118644067796,
#              (16, 9, False): -0.6901408450704225,
#              (15, 4, False): -0.8367346938775511,
#              (10, 1, False): -0.30434782608695654,
#              (21, 1, False): 0.7692307692307693,
#              (11, 1, False): -0.38461538461538464,
#              (21, 8, True): 0.9642857142857143,
#              (13, 9, False): -0.6041666666666666,
#              (21, 3, True): 1.0,
#              (21, 2, False): 0.8620689655172413,
#              (19, 2, False): -0.7380952380952381,
#              (21, 5, False): 0.8,
#              (12, 9, False): -0.43478260869565216,
#              (8, 9, False): -0.45454545454545453,
#              (5, 9, False): -0.5,
#              (15, 2, False): -0.8484848484848485,
#              (12, 2, False): -0.5490196078431373,
#              (8, 10, False): -0.7037037037037037,
#              (9, 8, False): -0.5,
#              (8, 8, False): -0.6470588235294118,
#              (16, 9, True): -1.0,
#              (18, 6, False): -0.8135593220338984,
#              (8, 6, False): -0.3333333333333333,
#              (16, 5, False): -0.6785714285714286,
#              (15, 1, False): -0.8301886792452831,
#              (16, 8, False): -0.6,
#              (21, 7, True): 1.0,
#              (18, 1, False): -0.7592592592592593,
#              (8, 1, False): -0.6428571428571429,
#              (10, 8, False): -0.16666666666666666,
#              (18, 10, True): -0.3125,
#              (11, 2, False): -0.5555555555555556,
#              (21, 9, False): 0.8648648648648649,
#              (9, 2, False): -0.75,
#              (5, 3, False): -1.0,
#              (17, 2, True): -0.7142857142857143,
#              (14, 4, False): -0.5740740740740741,
#              (9, 6, False): -0.35714285714285715,
#              (6, 6, False): -0.42857142857142855,
#              (14, 5, False): -0.6756756756756757,
#              (12, 4, False): -0.48936170212765956,
#              (19, 5, False): -0.8142857142857143,
#              (14, 6, False): -0.62,
#              (18, 8, True): -0.5714285714285714,
#              (16, 8, True): -1.0,
#              (13, 7, False): -0.8222222222222222,
#              (21, 2, True): 1.0,
#              (16, 5, True): -0.4,
#              (14, 7, False): -0.5319148936170213,
#              (12, 8, False): -0.74,
#              (21, 6, True): 0.92,
#              (10, 4, False): -0.16666666666666666,
#              (5, 4, False): -0.6,
#              (15, 9, False): -0.47058823529411764,
#              (6, 10, False): -0.4482758620689655,
#              (7, 8, False): -0.6,
#              (16, 2, True): -0.6666666666666666,
#              (19, 7, False): -0.8909090909090909,
#              (11, 4, False): 0.2222222222222222,
#              (18, 6, True): -0.5,
#              (8, 3, False): -1.0,
#              (15, 5, True): -0.2,
#              (16, 6, True): -0.45454545454545453,
#              (6, 2, False): -0.8,
#              (17, 1, True): -0.3333333333333333,
#              (10, 6, False): -0.10526315789473684,
#              (5, 6, False): -0.14285714285714285,
#              (10, 7, False): -0.55,
#              (12, 2, True): -0.6,
#              (14, 1, True): -0.2857142857142857,
#              (16, 3, True): -1.0,
#              (7, 9, False): -0.3333333333333333,
#              (15, 8, False): -0.7111111111111111,
#              (5, 10, False): -0.2857142857142857,
#              (14, 3, True): -1.0,
#              (4, 1, False): -0.3333333333333333,
#              (9, 5, False): -0.6666666666666666,
#              (7, 1, False): -0.42857142857142855,
#              (5, 1, False): -0.6666666666666666,
#              (6, 4, False): -0.75,
#              (15, 8, True): -0.7142857142857143,
#              (4, 8, False): 0.3333333333333333,
#              (15, 9, True): -0.7142857142857143,
#              (21, 4, True): 1.0,
#              (20, 4, True): 1.0,
#              (14, 4, True): 0.25,
#              (13, 5, True): -0.14285714285714285,
#              (19, 2, True): -0.7142857142857143,
#              (14, 2, True): 0.3333333333333333,
#              (14, 6, True): -1.0,
#              (6, 1, False): -0.5,
#              (13, 6, True): -0.6,
#              (19, 6, True): -0.7777777777777778,
#              (20, 9, True): 0.8181818181818182,
#              (14, 9, True): 0.0,
#              (4, 10, False): -0.5833333333333334,
#              (12, 4, True): 1.0,
#              (21, 7, False): 0.9375,
#              (8, 4, False): -0.8181818181818182,
#              (19, 8, True): -0.6,
#              (10, 9, False): 0.0,
#              (20, 8, True): 1.0,
#              (6, 8, False): 0.2,
#              (13, 2, True): -0.5,
#              (17, 5, True): -0.36363636363636365,
#              (7, 3, False): -0.5555555555555556,
#              (11, 7, False): 0.2631578947368421,
#              (7, 7, False): 0.0,
#              (9, 9, False): -0.4782608695652174,
#              (4, 3, False): -1.0,
#              (20, 5, True): 0.375,
#              (9, 4, False): -0.2857142857142857,
#              (20, 6, True): 0.375,
#              (20, 1, True): 0.0,
#              (18, 2, True): -0.75,
#              (15, 2, True): 0.0,
#              (13, 8, True): -1.0,
#              (16, 7, True): -1.0,
#              (19, 1, True): -1.0,
#              (4, 4, False): -1.0,
#              (18, 1, True): -0.8181818181818182,
#              (20, 2, True): 0.14285714285714285,
#              (14, 5, True): -0.3333333333333333,
#              (15, 1, True): -0.6,
#              (18, 7, False): -0.7021276595744681,
#              (19, 3, True): -0.3333333333333333,
#              (9, 7, False): -0.6470588235294118,
#              (16, 1, True): -1.0,
#              (12, 10, True): -0.875,
#              (6, 3, False): -0.8,
#              (14, 8, True): -1.0,
#              (12, 8, True): -1.0,
#              (13, 3, True): -1.0,
#              (17, 6, True): 0.0,
#              (13, 1, True): -0.25,
#              (15, 7, True): -0.42857142857142855,
#              (5, 8, False): -1.0,
#              (5, 5, False): -0.6,
#              (18, 3, True): -1.0,
#              (4, 6, False): 0.4,
#              (8, 7, False): -0.8333333333333334,
#              (15, 6, True): 0.2,
#              (15, 4, True): -0.6666666666666666,
#              (18, 9, True): -0.6,
#              (14, 7, True): -0.3333333333333333,
#              (5, 2, False): -0.5,
#              (18, 4, True): -1.0,
#              (4, 5, False): 1.0,
#              (17, 9, True): -0.7142857142857143,
#              (19, 4, True): -0.5,
#              (13, 4, True): -0.6,
#              (7, 6, False): -0.4,
#              (16, 4, True): -0.5,
#              (12, 7, True): 0.0,
#              (12, 1, True): -1.0,
#              (13, 9, True): -1.0,
#              (4, 9, False): -0.3333333333333333,
#              (4, 7, False): 1.0,
#              (12, 5, True): -0.3333333333333333,
#              (12, 6, True): -1.0,
#              (5, 7, False): -0.3333333333333333,
#              (17, 3, True): -1.0,
#              (4, 2, False): -1.0})
